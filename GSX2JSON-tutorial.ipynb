# %%
# Source: https://docs.google.com/spreadsheets/d/1H3kjJ-HJ3AvZKDr39ck7iKPAL7yumozkZIHQDZATCJQ

import requests
response = requests.get(
    "https://opensheet.elk.sh/1H3kjJ-HJ3AvZKDr39ck7iKPAL7yumozkZIHQDZATCJQ/1")
print(response)

res = response.json()
display(res)
# Out:
# <Response [200]>
# [{'material_id': 'MAT-001',
#   'material_name': '6061-T6 Aluminum Alloy',
#   'category': 'Metal',
#   'density_g_cm3': '2.7',
#   'youngs_modulus_gpa': '69',
#   'price_usd_per_kg': '4.2'},
#  {'material_id': 'MAT-002',
#   'material_name': '304 Stainless Steel',
#   'category': 'Metal',
#   'density_g_cm3': '8',
#   'youngs_modulus_gpa': '193',
#   'price_usd_per_kg': '3.1'},
#  {'material_id': 'MAT-003',
#   'material_name': 'Ti-6Al-4V Titanium Alloy',
#   'category': 'Metal',
#   'density_g_cm3': '4.43',
#   'youngs_modulus_gpa': '114',
#   'price_usd_per_kg': '28'},
#  {'material_id': 'MAT-004',
#   'material_name': 'AZ31B Magnesium Alloy',
#   'category': 'Metal',
#   'density_g_cm3': '1.78',
#   'youngs_modulus_gpa': '45',
#   'price_usd_per_kg': '6.5'},
#  {'material_id': 'MAT-005',
#   'material_name': 'C110 Copper',
#   'category': 'Metal',
#   'density_g_cm3': '8.96',
#   'youngs_modulus_gpa': '110',
#   'price_usd_per_kg': '9.2'},
#  {'material_id': 'MAT-006',
#   'material_name': 'GFRP (E-Glass/Epoxy)',
#   'category': 'Composite',
#   'density_g_cm3': '1.9',
#   'youngs_modulus_gpa': '25',
#   'price_usd_per_kg': '8'},
#  {'material_id': 'MAT-007',
#   'material_name': 'CFRP (Carbon/Epoxy)',
#   'category': 'Composite',
#   'density_g_cm3': '1.6',
#   'youngs_modulus_gpa': '70',
#   'price_usd_per_kg': '45'},
#  {'material_id': 'MAT-008',
#   'material_name': 'ABS Polymer',
#   'category': 'Polymer',
#   'density_g_cm3': '1.04',
#   'youngs_modulus_gpa': '2.1',
#   'price_usd_per_kg': '2.2'},
#  {'material_id': 'MAT-009',
#   'material_name': 'Polycarbonate (PC)',
#   'category': 'Polymer',
#   'density_g_cm3': '1.2',
#   'youngs_modulus_gpa': '2.4',
#   'price_usd_per_kg': '3.4'},
#  {'material_id': 'MAT-010',
#   'material_name': 'Alumina (Al2O3, 95%)',
#   'category': 'Ceramic',
#   'density_g_cm3': '3.75',
#   'youngs_modulus_gpa': '300',
#   'price_usd_per_kg': '12'}]

# %%
import pandas as pd
df = pd.DataFrame(res)
display(df)
# Out:
#   material_id             material_name   category density_g_cm3  \
# 0     MAT-001    6061-T6 Aluminum Alloy      Metal           2.7
# 1     MAT-002       304 Stainless Steel      Metal             8
# 2     MAT-003  Ti-6Al-4V Titanium Alloy      Metal          4.43
# 3     MAT-004     AZ31B Magnesium Alloy      Metal          1.78
# 4     MAT-005               C110 Copper      Metal          8.96
# 5     MAT-006      GFRP (E-Glass/Epoxy)  Composite           1.9
# 6     MAT-007       CFRP (Carbon/Epoxy)  Composite           1.6
# 7     MAT-008               ABS Polymer    Polymer          1.04
# 8     MAT-009        Polycarbonate (PC)    Polymer           1.2
# 9     MAT-010      Alumina (Al2O3, 95%)    Ceramic          3.75
#
#   youngs_modulus_gpa price_usd_per_kg
# 0                 69              4.2
# 1                193              3.1
# 2                114               28
# 3                 45              6.5
# 4                110              9.2
# 5                 25                8
# 6                 70               45
# 7                2.1              2.2
# 8                2.4              3.4
# 9                300               12
